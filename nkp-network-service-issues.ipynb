# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-service-issues/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Service Issues``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Network Service Issues](#networkServiceIssuestop)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topnetworkServiceIssuesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="networkServiceIssuestop"></a>
# ### [Network Service Issues](#networkServiceIssues)
#
# - [Course Introduction](#networkServiceIssues1CourseIntroduction) <br/><br/>
# - [Incorrect Gateway or Netmask](#networkServiceIssues2IncorrectGatewayorNetmask) <br/><br/>
#     - [Default Gateway](#DefaultGateway) <br/><br/>
#         - [Unreachable Default Gateway](#UnreachableDefaultGateway) <br/><br/>
#             - [Troubleshooting Netmask](#TroubleshootingNetmask) <br/><br/>
# - [Duplicate IP or MAC Addresses](#networkServiceIssues3DuplicateIPorMACAddresses) <br/><br/>
#     - [Duplicate IP](#DuplicateIP) <br/><br/>
#     - [Duplicate MAC](#DuplicateMAC) <br/><br/>
# - [Resolving Names](#networkServiceIssues4ResolvingNames) <br/><br/>
#     - [``nslookup``](#nslookup) <br/><br/>
#     - [Load Balancing](#LoadBalancing) <br/><br/>
#     - [DNS Forwarders](#DNSForwarders) <br/><br/>
#     - [Alternate DNS](#AlternateDNS) <br/><br/>
#     - [Attacks](#Attacks) <br/><br/>
#     - [Determine Problem](#DetermineProblem) <br/><br/>
#     - [Tools](#Tools) <br/><br/>
# - [Expired DHCP Scopes and Rogue DHCP Servers](#networkServiceIssues5ExpiredDHCPScopesandRogueDHCPServers) <br/><br/>
#     - [DHCP Scope](#DHCPScope) <br/><br/>
#         - [Properties](#DHCPScopeProperties) <br/><br/>
#             - [Troubleshooting](#TroubleshootingScopes) <br/><br/>
#     - [Rogue DHCP Server - MiTM](#RogueDHCPServerMiTM) <br/><br/>
#         - [Detection](#DetectingRogueDHCPServer) <br/><br/>
#         - [Mitigation](#MitigatingRogueDHCPServer) <br/><br/>
# - [Expired IP Addresses and Incorrect Times](#networkServiceIssues6ExpiredIPAddressesandIncorrectTimes) <br/><br/>
#     - [DHCP Lease Time](#DHCPLeaseTime) <br/><br/>
#     - [Expired IP Addresses](#ExpiredIPAddresses) <br/><br/>
#     - [Incorrect System Times](#IncorrectSystemTimes) <br/><br/>
#         - [Network Time Protocol - NTP](#ntp) | [Public Internet Time Servers](#ntp) <br/><br/>
# - [SSL Certificates and Blocked Ports](#networkServiceIssues7SSLCertificatesandBlockedPorts) <br/><br/>
#     - [Secure Sockets Layer - SSL](#ssl) <br/><br/>
#         - [Troubleshooting SSL Issues](#TroubleshootingSSLIssues) <br/><br/>
#             - [TCP Connection](#errorsTCPConnection) <br/><br/>
#             - [Certificate Failure](#ErrorsCertificateFailure) <br/><br/>
#             - [No Shared Cipher](#ErrorsNoSharedCipher) <br/><br/>
#     - [Blocked Ports](#BlockedPorts) <br/><br/>
# - [Incorrect Firewall and ACL Settings](#networkServiceIssues8IncorrectFirewallandACLSettings) <br/><br/>
#     - [Firewall Configuration Issues](#FirewallConfigurationIssues) <br/><br/>
#     - [Router ACL Misconfiguration](#RouterACLMisconfiguration) <br/><br/>
# - [Hardware Failures and Unresponsive Services](#networkServiceIssues9HardwareFailuresandUnresponsiveServices) <br/><br/>
#     - [Hardware Failures](#HardwareFailures) <br/><br/>
#     - [Unresponsive Services](#UnresponsiveServices) <br/><br/>
#         - [Event Viewer](#EventViewer) <br/><br/>

# %% [markdown]
# ### [Practice: Troubleshoot Network Service Issues](#practicenetworkServiceIssues)
#
# * [Exercise: Troubleshoot Network Service Issues](#exercisenetworkServiceIssues)

# %% [markdown]
# <a id="topnetworkServiceIssuesTest"></a>
# ### ⚡ [Test](#networkServiceIssuesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues"></a>
# ***
# ### Network Service Issues
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues1CourseIntroduction"></a>
# ***
# ###### Course Introduction
# ***

# %% [markdown]
# Cover some common issues that can arise with network services as well as how to resolve them including incorrect gateways duplicate, IP addresses and incorrect times.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues2IncorrectGatewayorNetmask"></a>
# ***
# ###### Incorrect Gateway or Netmask
# ***

# %% [markdown]
# After completing this topic, should be able to: ``correct issues relating to incorrect gateway or netmask``.
#
# Every system that uses TCP/IP as its communication protocol requires three configured values, if you want to be able to communicate with systems on your own subnet, as well as those outside of your subnet, or perhaps, most notably, the Internet:
#
#
# - IP address
#
#
# - Subnet mask
#
#
# - Default gateway
#
#
# Looking at some issues that can arise from incorrectly configured systems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DefaultGateway"></a>
# ***
# ###### Default Gateway
# ***

# %% [markdown]
# Enables the local network, and all the hosts on that network, to connect to an external network such as the Internet.
#
# A router is commonly used as a gateway - physical device itself is a router - because they are responsible for connecting networks together but it represents the means for us to leave our network and get to any other network, refer to it often as a gateway.
#
# The two terms - gateway / router - used interchangeably and this is the same for a home environment as it is for any kind of enterprise environment - to get to another network, you have to go through a router.
#
# Can also use a computer with two network adapters for a router or your gateway, as long as it has one adapter that is connected to the local subnet and another one that is connected to the outside network such as the Internet - in fact, just about every version of Windows Server has the ability to act as a router, so you don't need to go out and purchase an official router, for lack of a better word, but it really doesn't matter, as long as it does the job.
#
# Referred to as the default gateway, simply because any given device or any given application will use the gateway unless another one is specified, but it will also forward the packet to the default gateway.
#
# If it is deemed that the intended recipient is not within your subnet and that's actually the job of the subnet mask - it compares the destination to the subnet mask and, in essence, says that this packet is either destined for a host within the subnet or it's in some other network and if it's in some other network, then it will default to forwarding the packet off to the gateway.
#
# Can in fact have more than one default gateway defined, but in most cases, will see that there is only one and, in essence, that represents the way to get out of this network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="UnreachableDefaultGateway"></a>
# ***
# ###### Unreachable Default Gateway
# ***

# %% [markdown]
# If you are unable to reach the default gateway, then of course you need to isolate the problem, so begin with checking your own local IP configuration and of course the physical cabling if the problem is only affecting one host.
#
# If it's a problem with the router itself, which of course it could be, then it's likely affecting the entire subnet, so of course try to determine what the scope of the problem is.
#
# The subnet mask or often referred to as just the netmask, is a 32-bit mask that's used to divide an IP address - every IP address is divided into two sections, the network portion which identifies which network you are on and then the host portion which identifies the specific host on that network.
#
# Divides the network up into smaller subnets and then determines how many hosts can be on that subnet.
#
# See the binary values of ``1`` - if all set to ``1`` - the decimal value would equal ``255`` - the length is quite simply how many of those bits are set to ``1``.
#
# Would not see all ``1`` across the board in any practical implementation of subnetting.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Table of default subnet classes with five columns: ``Class``, ``Netmask length``, ``# of networks``, ``# of hosts``, and ``Netmask`` with three Classes, ``Class A``, ``B``, and ``C``.

# %% [markdown]
# - ``Class A`` has a Netmask length of 8, 126 networks, 16,777,214 hosts, and a ``255.0.0.0`` Netmask.

# %%
network,broadcast=1,1

# %%
2**7-network-broadcast
# Out:
# 126

# %%
2**24-network-broadcast
# Out:
# 16777214

# %% [markdown]
# - ``Class B`` has a Netmask length of 16, 16,382 networks, 65,534 hosts, and a ``255.255.0.0`` Netmask.

# %%
2**14-network-broadcast
# Out:
# 16382

# %%
2**16-network-broadcast
# Out:
# 65534

# %% [markdown]
# - ``Class C`` has a Netmask length of 24, 2,097,150 networks, 254 hosts, and a ``255.255.255.0`` Netmask.

# %%
2**21-network-broadcast
# Out:
# 2097150

# %%
2**8-network-broadcast
# Out:
# 254

# %% [markdown]
# The class simply defines the number of networks as well as how large they are in terms of how many hosts can be accommodated on that particular network, so can see that ``Class A`` networks are very large - they can contain millions of hosts, but there aren't very many of them, so the ``Class B`` is a little more reasonable, there are over 16,000 ``Class B`` networks, and they're fairly large, over 65,000 hosts - ``Class C``, there are million of them but they are all very small.
#
# But those are just the defaults and again, you see the length of the mask is either 8, 16 or 24 and that corresponds with the decimal values we see under the netmask column.
#
# - ``Class A`` is 8 bits enabled, the remaining 24 are off.
#
#
# - ``Class B`` is split right down the middle - 16 bits for the netmask length equates to ``255.255.0.0`` - 16 bits on, 16 off.
#
#
# - ``Class C`` is 24 bits on, 8 bits off for ``255.255.255.0``.
#
# But again, those are just starting points, can use different subnet masks to vary the size to whatever you need.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - [Seven Second Subnetting](https://nbviewer.org/github/SeanOhAileasa/nkp-network-concepts/blob/main/rc/networking-addressing/nkp-seven-second-subnetting.ipynb) [1]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="TroubleshootingNetmask"></a>
# ***
# ###### Troubleshooting Netmask
# ***

# %% [markdown]
# So when troubleshooting the subnet mask, we refer to any documentation that outlines what subnet a particular host should be on.
#
# Check the other devices and confirm that they are using the same subnet mask as you - should all match.
#
# All systems in the same subnet should have the same value for the subnet mask and this is certainly something that can happen if someone manually configured any particular host because a simple typo could make that host believe that they are in fact on a different subnet.
#
# Some of the tools you have to assist you in troubleshooting include some command line utilities, most notably ``ipconfig`` and/or ``ping``.
#
#
# - ``ipconfig`` will simply show you what values have been configured
#
#
# - ``ping`` can be used to test connectivity with other systems on your subnet, or of course the default gateway
#
#
# So you just ``ping`` its address, and if you get a response, you are able to see that system and if you don't get a response, then clearly something is wrong.
#
# These tools are installed by default on most operating systems and they can be used to determine how traffic is being directed throughout the network, so how far is it getting and is it being prevented from being routed externally?
#
# In other words, if I can ``ping`` the interface of the router that faces me but I can't seem to ``ping`` anything beyond that, then the problem likely is external but that still helps you to isolate where the problem is.
#
# So again, using a combination of these tools and approaches, you can hopefully isolate what the problem is but ultimately, you must have a valid IP address, a correct subnet mask and a default gateway that is up and running, to be able to fully internetwork with TCP/IP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues3DuplicateIPorMACAddresses"></a>
# ***
# ###### Duplicate IP or MAC Addresses
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot issues caused by duplicate IP and MAC addresses``.
#
# Looking at some problems may encounter if duplicate addresses are discovered in a network - begin with the IP address.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DuplicateIP"></a>
# ***
# ###### Duplicate IP
# ***

# %% [markdown]
# This issue occurs when the same IP address is assigned to two network devices within the same network.
#
# In that event, one or both devices can end up being disabled or, of course, just losing connectivity.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Can happen for a number of reasons, typically it's some kind of configuration error, particularly if the same static IP address was used twice.
#
# If you have a number of systems in your environment that are statically configured, then you need to ensure that all of the values are unique and that could just be a simple typo, for example, but an IP address in a DHCP range might still just be handed out to a client but perhaps the address it hands out is already being statically used by some other system.
#
# In many environments, the servers, for example, might be statically configured, so if that's the case, the DHCP scope that is configured has to exclude the values that are being statically used.
#
# The DHCP service itself might encounter an error, that's not as likely, but it is possible.
#
# Perhaps it could also be an issue of a system returning online, something that has been turned off for quite some time, and it had a particular address that has now been assigned elsewhere, so when that system comes back online, it still has that old address and, of course, now you have the duplicate issue.
#
# This is certainly more of an issue if you are using a lot of static IP addresses in your environment - if you have many administrators and many systems that are being configured statically, of course, you are more likely to encounter the same address being assigned twice, so it just becomes important to document the allocation and, of course, to verify which systems are using which addresses and just ensure that there aren't any duplications.
#
# Static addresses do not change, so once it's set, it stays that way forever, so, again, just verify that it is correct, and that it is unique.
#
# Now this does involve a little more administrative overhead to configure these IP addresses statically, so it's not ideal for larger networks but it can be a little more stable and a little more reliable because any system that does have a static address no longer has to rely on a DHCP server to assign it its address, so if you know that any given system is basically always going to stay put in terms of its network location and is always going to use that address, by all means, configure it manually - now you have fewer systems to deal with in terms of DHCP but again, you just have to ensure that you do not assign duplicate addresses statically and whichever addresses are being used statically must be exempted from the DHCP server scope.
#
# In terms of troubleshooting duplicate addresses, certainly review the documentation.
#
# ``ping`` the address first - if it responds, then, of course, it is already in use.
#
# Perhaps refer to MAC address tables - switches maintain MAC tables whereby it knows which device is using any given IP address and you can also do some packet capturing if you really need to be detailed but in most cases, at least with Windows systems, they're pretty good at detecting it, as soon as you boot up a system that does cause a conflict, it should actually tell you that it is detecting this address elsewhere in the environment but unfortunately it does not say which system is using it.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DuplicateMAC"></a>
# ***
# ###### Duplicate MAC
# ***

# %% [markdown]
# Duplicate MAC addresses are far less common, but they can occur - the MAC address refers to the 12-digit hexadecimal number, which is 48 bits in length.
#
# That is sourced directly from the hardware, the network interface card itself has this address burned into it and the address is globally unique and assigned by the manufacturer, so it's not very common to have manufacturers produce network cards with duplicate addresses but it has happened in the past because they think an address that was used quite some time ago is now defunct, so it's possible, but very unlikely.
#
# Generally, duplicate MAC addresses occur when the vendor-assigned address is not used, in other words, it's replaced with a self-assigned address or what's referred to as a locally administered address - again, this is not particularly common either but there are certain adapters that allow you to effectively change what MAC address is going to be used for that device.
#
# Can find out what address is being used with the ``ARP`` utility - can view or modify the ``ARP`` cache and the entries include the MAC addresses and it basically says that this MAC address is currently using this IP address and the ``ARP`` utility does allow you to view and/or modify those values, so you can use this to troubleshoot problems that are related to duplicate IP addresses or MAC addresses but again, in most cases, almost all network administrators are generally fine with using the burned in MAC address but if it is a case, for example, where a server has a faulty network adapter card, and you replace the adapter card, then you do have to assign the IP address that was being used for that system to the same adapter but now there is a different MAC address, so you do have to update some of the values, possibly, in some ``ARP`` caches to ensure that they are aware of the new MAC address using that old IP address.
#
# Again, that might not be an issue because ``ARP`` caches don't remain current for all that long - only about two minutes, by default, so if the cache is simply left to purge out, then ultimately it will update itself anyway but it can be an issue if you have these very important systems that need to be able to communicate via the MAC address and the IP address, so changes can result in problems but again, issues with duplicate MAC addresses are far less common than issues with duplicate IP addresses but always something to be on the lookout for.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues4ResolvingNames"></a>
# ***
# ###### Resolving Names
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot issues where names are not resolving``.
#
# Looking at troubleshooting ``DNS`` or the ``Domain Name System`` - this is the service used to translate domain names into IP addresses and as such ``DNS`` is relied upon heavily for Internet browsing and email services because of course we, as users, generally do not know the IP addresses of the systems we want to reach, but we do know their names
#
# ``DNS`` issues can generally result in the inability for users to connect to websites or Internet hosts and often browsers will report ``No Internet Access`` if the ``DNS`` service is unavailable which can, in some cases, lead you to believe that it might be a problem with the default gateway because it seems like we have no Internet, but if you do know the actual IP address of even one Internet site, you can enter that into your browser and if this site comes up, then clearly it's not a problem with the router but rather with the ``DNS`` service itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="nslookup"></a>
# ***
# ###### ``nslookup``
# ***

# %% [markdown]
# The ``nslookup`` utility can be used for troubleshooting your internal ``DNS`` issues, in essence, trying to determine if the ``DNS`` server is responding to your request and/or specifically, which server is responding.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="LoadBalancing"></a>
# ***
# ###### Load Balancing
# ***

# %% [markdown]
# Load balancing refers to having multiple servers and distributing the workload across those servers, but in those cases, it can be difficult to know which server has failed and this can result in intermittent connectivity, because you might hit a server that is perfectly fine one time and then you hit a server that is down, the next, so you get this intermittent connectivity.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DNSForwarders"></a>
# ***
# ###### DNS Forwarders
# ***

# %% [markdown]
# There can also be issues with ``DNS`` forwarders, any given ``DNS`` server has its database, but it can also be configured to forward a request off to a different server if it does not have the record that you are requesting, so if a particular domain, for example, is continuously being requested, and the server you are hitting is configured to forward all of those requests to a specific server that has gone down, then all of them will fail.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="AlternateDNS"></a>
# ***
# ###### Alternate DNS
# ***

# %% [markdown]
# Alternate ``DNS`` refers to the fact that most organizations have a primary and a secondary ``DNS`` server, so it's similar to load balancing in that there are two servers but the secondary is never used unless the primary goes down or fails, so if you suspect that's the problem and you do switch over to the secondary, you can confirm if the problem relates to the primary server, so again, it's just an alternate, a standby.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="Attacks"></a>
# ***
# ###### Attacks
# ***

# %% [markdown]
# Will and of course, you also want to rule out malware or attacks - there could be a ``DNS`` poisoning attack that alters the records and of course, there could be any other kind of malware that might affect the service itself, such as a denial of service attack or a virus or just anything that brings down the service.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DetermineProblem"></a>
# ***
# ###### Determine Problem
# ***

# %% [markdown]
# When trying to determine what the problem is, of course, verify the network connectivity.
#
# > Is the ``DNS`` server itself online?
#
# > Can you see it?
#
# So ``ping`` it to determine if it is even alive and responding to any kind of request and then, of course, determine who is being affected.
#
# > Is it just one user or is it the entire subnet?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="Tools"></a>
# ***
# ###### Tools
# ***

# %% [markdown]
# In terms of some of the tools that you can use, ``ping``, of course, allows you to simply test, is the server responding, but what you would want to do is ``ping`` it by both its IP address and its name because the ``DNS`` server itself should be able to resolve its own name, so if it works by the IP address but not by the name, then there is a problem with the service and again, the ``nslookup`` utility can test the name resolution, it returns the name and the IP address of the ``DNS`` server, so you can find out if it's the correct server and of course what its actual address is just in case you have the IP address set wrong in your own system - if your system believes that it should be contacting IP address X but the ``DNS`` server is, in fact, IP address Y, then it's not a problem with the server, it's a problem with your own configuration.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Summary
# ***

# %% [markdown]
# Ultimately, ``DNS`` is, again, pretty much required these days for Internet connectivity, and even just being able to resolve names within your own internal environment, so it's a very important service and something you always want to keep on top of in terms of monitoring its health and status.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues5ExpiredDHCPScopesandRogueDHCPServers"></a>
# ***
# ###### Expired DHCP Scopes and  Rogue DHCP Servers
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot issues caused by expired DHCP scopes and rogue DHCP servers``.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DHCPScope"></a>
# ***
# ###### DHCP Scope
# ***

# %% [markdown]
# Troubleshooting some ``DHCP`` issues, beginning with the scope itself.
#
# This is something that you configure on the server and it represents the valid range of IP addresses that are available for assignment and any one address from that range is leased to the client computers for a certain amount of time and that is configurable as well.
#
# The scopes are configured to designate a pool of IP addresses - the server can then allocate to the ``DHCP`` clients.
#
# The clients are required to be configured to use ``DHCP``, in other words, you have a choice, can set the client to use a static configuration or you can simply tell it to obtain an IP address automatically, in which case you are telling it to request its configuration from a ``DHCP`` server.
#
# Now this in fact is the default on Windows systems, but it can certainly be changed.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DHCPScopeProperties"></a>
# ***
# ###### DHCP Scope Properties
# ***

# %% [markdown]
# With respect to the scope itself, there are several properties, these are only a few examples:
#
#
# - does of course have to indicate the network ID and the subnet mask that you are going to use.
#
#
# - the actual IP address range, the starting address through to the ending address.
#
#
# - the lease duration and this is typically around a week by default for most systems but you can set it to really just about any value you want and it typically comes down to how many clients you have versus how many addresses you want to configure within a scope and the idea being that if you have only a few addresses but a lot of systems that maybe aren't all on at the same time, such as shift work, then you would typically have a fairly short lease duration, if you have the exact opposite, a lot of addresses and not that many clients, then any one client can keep that configuration for a fair amount of time, so again, the duration is your call but seven, eight days is usually around the default.
#
#
# - the name of the scope is simply what you can call it.
#
#
# - an exclusion range is a set of addresses that falls within the scope, but that should not be assigned, so let's just say, your scope is ``192.168.1.100`` to ``200``, normally, it would assign out every one of those addresses from ``100`` to ``200`` but if you know, for example, that ``150`` to ``160`` is already being used because they've been statically assigned to maybe ten servers, we'll say then that represents the exclusion range, so again, it's really just only values that would normally fall within the range that you just don't want to assign.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="TroubleshootingScopes"></a>
# ***
# ###### Troubleshooting Scopes
# ***

# %% [markdown]
# So when troubleshooting scopes, some common issues can include:
#
# - the ``DHCP`` scope itself not being activated, this is generally an option you can configure when you are setting things up initially, for example, you might have many scopes that you need to create, but you don't have to activate them right then and there, as soon as it is activated, the server will start allocating those addresses, but maybe you just don't want it to do so yet - can leave them in a deactivated state until everything is fully configured but of course, if it was supposed to be activated and you just forgot, well then clearly that's a problem.
#
#
# - the lease configuration - anything wrong with the lease in terms of the duration and/or the validity periods - Maybe you just made a mistake there.
#
#
# - limited scope typically refers to a scope that does not have enough addresses to assign all of the clients, so you just made it too small basically.
#
#
# - the ``DHCP`` service itself might have been stopped, any given service on any given server could fail at any point, so if that service does fail, then that server will stop allocating addresses.
#
#
# - perhaps something has simply been misconfigured on the client side - the ``DHCP`` client service may have failed, maybe somebody set a particular client system to be statically configured and they weren't supposed to, something along those lines, so there can certainly be a lot of issues.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="RogueDHCPServerMiTM"></a>
# ***
# ###### Rogue DHCP Server - MiTM
# ***

# %% [markdown]
# Might also encounter a rogue ``DHCP`` server, which is simply an unauthorized ``DHCP`` server appearing on a network, one that is not under administrative control.
#
# This is often used in man-in-the-middle attacks, because every version of Windows Server, for example, allows you to create a ``DHCP`` scope, so an attacker could very easily create a new ``DHCP`` server and then start handing out bogus IP address configurations to redirect clients.
#
# It offers the same services as an authorized ``DHCP`` server, so it will absolutely supply you with an IP address, a default gateway, and a DNS server but of course, if it is an unauthorized server doing so, that address configuration would be incorrect.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DetectingRogueDHCPServer"></a>
# ***
# ###### Detecting Rogue DHCP Server
# ***

# %% [markdown]
# Can try to detect rogue ``DHCP`` servers by using the ``DHCPLOC`` or locate utility - is a free download available from Microsoft, which is quite simply used to detect the presence of an unauthorized ``DHCP`` server.
#
# Can also use the ``ipconfig /all`` command on any given client to confirm the IP address of the ``DHCP`` server because, of course, a rogue ``DHCP`` server would not have the same IP address as an authorized server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="MitigatingRogueDHCPServer"></a>
# ***
# ###### Mitigating Rogue DHCP Server
# ***

# %% [markdown]
# So in terms of mitigating rogue ``DHCP`` servers, you can:
#
#
# - implement intrusion detection systems - this does require the appropriate signature to detect ``DHCP`` packets.
#
#
# - use multi-layer switches which are capable of dropping packets that aren't authorized.
#
#
# - implement ``DHCP`` snooping, which also drops ``DHCP`` messages that are not trusted.
#
#
# If you are in a Windows - Active Directory environment - the Active Directory itself, authorizes ``DHCP`` servers but this, of course, would only be applicable to Windows/Active Directory client systems, they are then informed to not accept an IP address configuration from any server that is not authorized but again, that's only applicable to Windows and Active Directory environments - anything other than that would not be able to detect, of course, the presence of an Active Directory authorized ``DHCP`` server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Summary
# ***

# %% [markdown]
# Ultimately, it's something that you want to keep on top of, and ensure that your clients are getting the correct information from the correct servers and if there are problems, then of course, as mentioned, double-check the address of the server, double-check the status of the service itself, and of course, the configuration that you are receiving from that server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues6ExpiredIPAddressesandIncorrectTimes"></a>
# ***
# ###### Expired IP Addresses and Incorrect Times
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``correct issues caused by expired ip addresses and incorrect system times``

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DHCPLeaseTime"></a>
# ***
# ###### DHCP Lease Time
# ***

# %% [markdown]
# Looking at how time can affect the configuration of a system, particularly with respect to DHCP, as well as some other components.
#
# When it comes to your IP address configuration that you receive from a DHCP server, there is always what's known as a lease duration on that configuration, meaning that you have it for a certain amount of time before it has to be renewed and this is applicable to basically any type of device, whether it's a laptop, a desktop, a smartphone, even a smart TV these days, or a tablet.
#
# Those types of devices toward the bottom there, the smartphones, the smart TVs, and tablets, certainly much more common in a home environment, but it's the same idea, that any time you get an IP configuration from a DHCP server, there is this time associated with the lease.
#
# In terms of the optimum length of what that time should be, it really is up to you, but in an environment such as a small home network, typically there are more addresses than devices, so in that case, you can have a longer lease period because it's unlikely that you will run out of addresses.
#
# Most home routers, for example, default to have about a 100 addresses available, and it's usually something in the ``192.168.``, let's just say ``1.100`` to ``200`` range - that's fairly common, so that represents 100 available addresses, so the chance that you would have more than 100 devices leasing IP addresses from that server in a home environment is fairly low.
#
# But if you are in a coffee shop, for example, then you might have many guests using your Wi-Fi, but only for a short period of time, so in this case, a shorter lease period would make much more sense, don't want someone to lease an address for, let's say, a week, when they are only going to be there for half an hour, so you can adjust the length of the lease quite a lot, but it ultimately does come down to how long you feel is appropriate for any given device to have the same address configuration.
#
# In a corporate environment, again, the default is usually around a week for most devices to have a valid address configuration, but again, if you have far more addresses than devices, you can look at increasing that validity period if you want to or if you have the exact opposite, more devices, not that many addresses, you can still shorten it - really comes down to whatever you feel is appropriate.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ExpiredIPAddresses"></a>
# ***
# ###### Expired IP Addresses
# ***

# %% [markdown]
# An expired IP address is essentially the fact that your lease does expire, so you can lose the network configuration for any given network.
#
# This might interfere with other devices or services if a device continues to use an IP address from an expired lease, so, again, the idea is if you did receive a particular configuration from a DHCP server and the lease says it's ``x`` amount of days, then, of course, at that point in time, when the expiry comes, that configuration is no longer valid, if your system is turned on and is able to contact the DHCP server, it will simply request a new configuration and you shouldn't have too much trouble at that point - but of course, you might lapse over the expiry time with your system turned off.
#
# Maybe you know, for example, that the lease configuration is going to expire, maybe let's say at the end of today, but if you shut down your system and then leave for a long weekend or something like that, then that address is still attached to your device the entire time it's off and then when you boot it up, let's say, maybe over the weekend if you're at home because it was a laptop, then it's possible it will still try to use that expired lease and it might interfere with trying to get an address in your home network or something along those lines.
#
# In the meantime, the server itself might attempt to lease the same IP address to another client on the network because it believes that address, since it did expire, in essence, is now available, so it might lease it out to someone else, so then you come back to work on Monday morning and you boot up your system and it still has that old address, then you might end up with an IP address conflict, so again, it depends on the duration and the state of the system when that expiry happens, so these aren't particularly common scenarios, but they can arise.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="IncorrectSystemTimes"></a>
# ***
# ###### Incorrect System Times
# ***

# %% [markdown]
# The time on the system itself - might be incorrect - computer clocks can be inaccurate, and this applies to servers, workstations, and any other network device that maintains the time.
#
# In some cases, they can still be configured manually and this effectively refers to the fact that the clock can be maintained by a battery, which can drift slightly on any given day, if the battery is getting low, for example, very often you will notice the time starting to lag behind a little bit, and that can have an effect because time synchronization is critical for logging, managing, securing, planning, and debugging and can also cause network issues, such as the inability to join an Active Directory domain, and various other synchronization problems and this comes down to the fact that clients, in essence, need to agree on what time it is as per their servers - the Kerberos protocol, for example, in a Windows Active Directory environment only has a tolerance of five minutes.
#
# If they do not agree that the time is within that five minutes - by default - then it will not let that client participate because it can throw off logging and managing and securing those systems.
#
# Particularly, when it comes to security, if the time is way off, then whatever it did log in terms of security just does not represent the correct time and that can also have an effect on your DHCP lease if the time is not correct.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ntp"></a>
# ***
# ###### Network Time Protocol - NTP | Public Internet Time Servers
# ***

# %% [markdown]
# Can also implement things such as the Network Time Protocol to try to prevent this - this can be used to synchronize hundreds of millions of devices and computers.
#
# There are also public Internet time servers - ``http://www.pool.ntp.org/`` - this allows you to synchronize with these, for lack of a better word, universal time servers, so that they do agree on what time it is, that's, in essence, the purpose of these protocols, so that everyone is synchronized to the same time.
#
# This way you know that your logs, and your security settings, and your policies, and your DHCP leases are all operating on systems that agree on what time it is.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues7SSLCertificatesandBlockedPorts"></a>
# ***
# ###### SSL Certificates and Blocked Ports
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot issues caused by untrusted SSL certificates and blocked tcp/udp ports``.
#
# Cover some issues that you might encounter with SSL certificates and open ports.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ssl"></a>
# ***
# ###### Secure Sockets Layer - SSL
# ***

# %% [markdown]
# SSL is the Secure Sockets Layer, and this is a standard security protocol that protects information transmitted online, so when you are doing things such as online banking or shopping online, this protects your information - it establishes encrypted links between web servers and browsers, so that your communication is secure.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="TroubleshootingSSLIssues"></a>
# ***
# ###### Troubleshooting SSL Issues
# ***

# %% [markdown]
# If you do need to troubleshoot some SSL issues, there are several tools available.
#
# ``SSL Labs`` is an application that you can use to check for problems with public accessible secure web servers and it can show problems about certificate verification, and also potential problems with specific TLS, or Transport Layer Security, clients.
#
# ``Wireshark`` can be used to analyze the handshake between the two, the negotiation process.
#
# ``OpenSSL`` can be used to debug the commands that are actually being issued between the two - the specific commands are ``s_client``, secure client, and ``s_server``, and ``x509`` refers to the actual format of the certificate itself, so you can actually capture and see those commands, and essentially try to find out what is going on as they negotiate the connection.
#
# Some of the common problems you might encounter include checking to see if the server requires ``SNI`` - ``Server Name Indication`` - this can be used with some of the commands in ``OpenSSL`` to verify that the name of the server matches the name on the certificate.
#
# You can check for missing certificates, if they are simply not present at all.
#
# You can check for a trusted root certification authority, every certificate that you ever implement has to initially come from a root server - then there is usually a hierarchy below that so you can verify the Root-CA is correct.
#
# You can verify client certificate issues, perhaps it is a certificate that was installed on the client that's causing the problem, not the server.
#
# You can confirm if TLS is being used, again, TLS is effectively a newer implementation of SSL, and some older browsers or older clients might not support it.
#
# You can also check the supported protocols with respect to encryption or ciphers to make sure that you have something that is supported on both ends.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="errorsTCPConnection"></a>
# ***
# ###### Errors - TCP Connection
# ***

# %% [markdown]
# Some errors might include a TCP connection failed or timed out error, so, quite simply, check the status of your TCP connection, perhaps some analyzing of the packets might be required there.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ErrorsCertificateFailure"></a>
# ***
# ###### Errors - Certificate Failure
# ***

# %% [markdown]
# i. there might also just be a failure with the certificate itself, such as a missing chain of certificates, as mentioned, there is always the root, then there are usually issuing servers in a hierarchy below the root, so you can find out if any component of that hierarchy is missing, meaning that you might have gotten a certificate from an invalid route.
#
#
# ii. the certificate itself might simply have expired.
#
#
# iii. the verification might have failed.
#
#
# iv. there might also be an invalid system time, so, again, we see time coming into play, whereby there needs to be agreement between the two systems as to what time it is because if they don't agree, then a certificate that has actually expired might be treated as not yet expired because of the disagreement in time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ErrorsNoSharedCipher"></a>
# ***
# ###### Errors - No Shared Cipher
# ***

# %% [markdown]
# There might also be no shared cipher that is supported between the two.
#
# Again, the client and server have to agree on what encryption algorithm is going to be used, so it has to be supported on both sides - could be an issue of an unknown protocol, again, possibly TLS related because TLS is newer than SSL, older browsers, older clients might not support it.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="BlockedPorts"></a>
# ***
# ###### Blocked Ports
# ***

# %% [markdown]
# With respect to blocked ports, ports simply represent the endpoint of communication for specific applications and services.
#
# There are ``1024`` well-known port numbers for services that are very common within most environments and most applications - used for both TCP or UDP.
#
# This comes down to the method of transmission, again, TCP uses acknowledgements and is a little more reliable, but UDP is a little faster because it does not use acknowledgements, but each of them have ports for their specific applications, and you quite simply need to know which ports need to be open in terms of communication.
#
# Can use a port scanner to determine if any ports are open on a network and they can be used to scan a single port, a range of ports, or look for any vulnerable ports, in other words, ports that should not be open, but are.
#
# With respect to whether or not a port should be open comes down to whether or not you are using that service or that application.
#
# Quickly referring back to ``SSL``, for example, uses port ``443``, so, clearly, if you want your environment to be able to use SSL, then ``443`` needs to be open.
#
# If you have any other service that you are not using, such as ``Telnet``, for example, then that port should be closed, that's port ``23``.
#
# This, of course, just gives you a little extra security, because if the port is entirely closed, then an attacker cannot use that port to try to get into your environment, so by scanning for the vulnerable ports, those that are open but aren't being used, you can, of course, improve the security of your environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues8IncorrectFirewallandACLSettings"></a>
# ***
# ###### Incorrect Firewall and ACL Settings
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot issues cause by incorrect firewall and acl settings``.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="FirewallConfigurationIssues"></a>
# ***
# ###### Firewall Configuration Issues
# ***

# %% [markdown]
# Cover some basic firewall configuration issues that you might encounter and of course, any kind of problem with the firewall, can result in loss of connectivity because firewalls, of course are designed to block traffic.
#
# One of the first things is to just check the management interface of the firewall itself, with respect to its IP address, its subnet mask and its default gateway - it's an interface like anything else, so it needs to have an IP configuration that is correct and valid.
#
# Might also just need to check the network configuration, such as, the physical connectivity - verify cabling to the device and that it is located correctly.
#
# Should also verify the logging, now, depending on what you are using for a firewall, it might be able to log to a local drive, for example, if it's a host-based firewall, then it's installed on some kind of server, for example, so you can log to the local drive but you can also send the logs to a remote drive on some other system and this includes what's known as the ``Syslog``, to simply find out what has been happening with that firewall.
#
# Verify the actual security rules that have been configured, to ensure that you are allowing the appropriate traffic while disallowing the undesirable traffic.
#
# Verify how ``NAT`` - ``Network Address Translation`` - is being handled and this refers to the security policy that you have implemented and that is quite generally the rules that you have set.
#
# > Does Network Address Translation happen before the security policy is applied or after?
#
# That can have an effect on communications, so you might need to check with the manufacturer to confirm, in fact, how it is handled on a particular device - it might also be configurable, again, it depends on actual firewall itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="RouterACLMisconfiguration"></a>
# ***
# ###### Router ACL Misconfiguration
# ***

# %% [markdown]
# ``ACL`` - ``Access Control Lists`` - always maintain the source and the destination traffic information, including the IP address, the zone such as Internet versus Intranet, and which interface the rules are configured on, so you always need to ensure that you have the correct information in the Access Control List - as to what is allowed, what is not allowed.
#
# Any kind of Router ACL misconfiguration might prevent legitimate access or conversely, fail to prevent unauthorized access, so of course you need to review these - need to make sure that the appropriate traffic is allowed and that the traffic you don't want, of course, is not allowed.
#
# Auditing should be implemented fairly frequently with respect to your firewalls to ensure that the configuration is in line with your policy and it does tend to change, things evolve as your environment grows and goes through different configurations of devices and applications, so it's generally something that you do need to keep on top of to ensure that your firewalls and their configuration remain consistent with what kind of traffic you want to allow and disallow.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssues9HardwareFailuresandUnresponsiveServices"></a>
# ***
# ###### Hardware Failures and Unresponsive Services
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``correct issues caused by hardware failures and unresponsive services``.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="HardwareFailures"></a>
# ***
# ###### Hardware Failures
# ***

# %% [markdown]
# With respect to a network device and any kind of hardware failure, it should be relatively straight forward to troubleshoot, if, for example, a device just ceases to function without any kind of configuration change then hardware is likely the issue.
#
# If your switch just stops switching, or your router just stops routing, and you know you haven't done anything to it, then of course, hardware becomes a likely candidate - not always that straightforward.
#
# Firmware issues can complicate certain situations, perhaps, you just applied a firmware update, you reboot the system and you sort of walk away assuming that everything is going to be fine but all of a sudden things aren't fine, well, of course, that might have been the issue.
#
# But if, for example, you have a switch that just stops switching and as mentioned you have done nothing to it, well, certainly don't instantly assume the hardware is the problem, confirm that the device is still operating.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ``ping`` - see if you get a response.
#
# Then physically check the advice for the obvious.
#
# > Does it have power?
#
# > Is it connected?
#
# Remember the status lights there, the entire switch can be disconnected from its uplink on a single port, so that can disable the entire switch in some cases.
#
# Certainly check the obvious but if all of that looks to be in order and you still are getting nothing, the entire switch itself could be down, so perhaps, you can just try to swap it out if you have a spare and of course, if everything works with the new one, clearly, then hardware was the problem.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="UnresponsiveServices"></a>
# ***
# ###### Unresponsive Services
# ***

# %% [markdown]
# Services are the core components of the Windows operating system - in essence, represent all of the little tasks that an operating system has to do to perform its overall job and services run in the background, and can be configured as either automatic with a delayed start, meaning that they don't start until something requests it to or just automatic across the board, meaning, it always starts, every time the server reboots.
#
# Manual is you have to start it yourself.
#
# Disabled means it will never start, it is entirely turned off.
#
# So depending on how you want your server configured, you can set those values yourself and of course, disabling services that are not being used is in fact recommended because if it's running for no reason, it represents a method by which that server can be attacked but essentially you just want to go through the services and verify that they are configured correctly.
#
# Some examples include:
#
#
# - the Active Directory Service itself, this runs on domain controller servers
#
#
# - the Background Intelligent Transfer Service, which is responsible for things such as Windows Update
#
#
# - DNS Server and/or Client Service, depending on whether or not you are the client or the server
#
#
# - DHCP Server and Client Service
#
#
# - Server Service, which is actually responsible for being able to share folders and files and printers - even if you are just a client system, you still have a server service because Windows clients can still share their folders, files, or printers
#
#
# - Remote Desktop Services, which allow people to connect remotely into any given system.
#
#
# Can use the services console which is a graphic interface to configure or view the status of your services, so if you want it to be disabled or set to automatic, you can just double-click the service and you can set that property.
#
# Can also use PowerShell or the command prompt to configure your services, but really it's up to you.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="EventViewer"></a>
# ***
# ###### Event Viewer
# ***

# %% [markdown]
# So again, it's just a matter of verifying which services should be running and of course, those that should be, need to remain running, so from time to time, you might encounter an unresponsive service, meaning, it is supposed to be running but it's not running, or even if it is, it's just not responding - things don't work perfectly 100% of the time, so you can check in your Event Viewer, which collects and stores information about events occurring on a system by default, so something like a service stopping unexpectedly will always log an event that you can see in the Event Viewer.
#
# Can verify in a couple of places in Event Viewer, in other words, there are different types of logs:
#
#
# - ``Windows Logs`` > ``Application`` - shows you the services that are running that are specific to a particular application
#
#
# - ``Windows Logs`` > ``System`` - shows you the status of services that have stopped, started, crashed or failed but specifically, related to the operating system, or simply the server itself, if you will.
#
# Make sure you check both of those when it comes to trying to troubleshoot errors with unresponsive services.
#
# Now if it is just a matter of the service having been stopped, and everything else on the server seems to be fine then you can absolutely just restart the service, you typically do not have to do something like a full reboot just to get a single service to load again - every service has the option to stop it, start it, pause it and then resume it, so again, if it was just mistakenly stopped, for example, just turn it back on again but if somebody configured it, and again, possibly, mistakenly to be disabled, then it will not turn itself back on, no matter how many times you reboot that server, it is in a disabled state, so it's up to you to set it back to the correct state and then start it again.
#
# But if it's multiple services that have crashed, then it might be better to just reboot the server to restart them all but again, in some cases, that's just not an option - can't just reboot servers, particularly in the middle of the day, because of course, they might disrupt users that are doing other things but of course, if the services are failing all over the place, well, the clients are not going to be able to get what they want from that server anyway, so it probably wouldn't hurt to reboot it at that point.
#
# But ultimately, it's just something else that you need to keep on top of, if the service has failed, it is not supplying the service the client needs, so whatever you can do to get that service running again, certainly, should be done.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="practicenetworkServiceIssues"></a>
# ***
# ### Practice: Troubleshoot Network Service Issues
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot network service issues``.
#
# i. Describe why a duplicate IP address might occur.
#
#
# ii. Describe issues relating to an incorrect subnet mask.
#
#
# iii. Describe a rogue DHCP server and its effect on clients.
#
#
# iv. Lst the configurable states of a Windows service.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="exercisenetworkServiceIssues"></a>
# ***
# ###### Exercise: Troubleshoot Network Service Issues
# ***

# %% [markdown]
# i. Describe why a duplicate IP address might occur.
#
# There can be a few different reasons, but most often this is due to the use of static IP addresses. If you are manually configuring systems with a preconfigured block of addresses, let's say, you're simply more likely to assign the same address twice.
#
# So if you are doing this, which is perfectly fine, by the way, you just need to be careful - make sure that there are no typos - make sure that it's documented with respect to which address is assigned to which system - also need to ensure that if you are using, let's just say, a block of static addresses, that they don't overlap at all with what is being assigned by a DHCP server.
#
# Need to ensure that they, effectively, avoid each other, so that the DHCP server does not issue out an address that has already been statically assigned - either way, will end up with the same problem, the duplicate IP address.

# %% [markdown]
# ii. Describe issues relating to an incorrect subnet mask.
#
# Quite simply, any kind of mistake in the subnet mask, in most cases, will prevent you from being able to connect to other clients entirely.
#
# Your system will likely believe that it's on a different subnet, so it won't be able to communicate with anyone - in short, you need to verify that all systems in the same subnet have the exact same subnet mask.

# %% [markdown]
# iii. Describe a rogue DHCP server and its effect on clients.
#
# The rogue is simply an unauthorized DHCP server, and it's often used in man-in-the-middle attacks to assign bogus IP address configurations to redirect clients to something like a malicious website.
#
#
# Basically, it's just a DHCP server that has appeared on the network without the knowledge or the consent of administration.
#
# It's fairly easy to do this if you have physical access to the network and since DHCP is broadcast-based, all of the clients, in essence, will see that DHCP server, so if they can get it to assign these addresses to those clients, then, in essence, they have an invalid configuration and, again, can be misused.

# %% [markdown]
# iv. List the configurable states of a Windows service.
#
# - can be set to Automatic with a delayed start, meaning it will wait until something requests it
#
#
# - can be just Automatic, which means it always starts every time the server reboots
#
#
# - can be set to Manual, which means you, as an administrator, you have to start it
#
#
# - can be Disabled, or entirely turned off
#
# If you do have services that you are not using, in fact, they should be disabled, so that you don't give an attacker a means to gain access to that server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkServiceIssuesTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[1] J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," professormesser.com, March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
